# %% [markdown]
# # Homework Assignment #1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Section 1: Police Killings

# %%
killings = pd.read_csv('../data/police-killings.csv', index_col=[0])
killings.head()
# Out:
#                  name  age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# ...

# %% [markdown]
# ### 1. Make the following changes to column names:
#
# - Rename "lawenforcementagency" to "agency"
# - Rename "raceethnicity" to "race"

# %%
killings.rename(columns = {'lawenforcementagency':'agency'}, inplace = True)
killings.rename(columns = {'raceethnicity':'race'}, inplace = True)

# %%
killings
# Out:
#                         name  age  gender             race     month  day  \
# 0         A'donte Washington   16    Male            Black  February   23
# 1             Aaron Rutledge   27    Male            White     April    2
# 2                Aaron Siler   26    Male            White     March   14
# 3               Aaron Valdez   25    Male  Hispanic/Latino     March   11
# 4               Adam Jovicic   29    Male            White     March   19
# 5              Adam Reinhart   29    Male            White     March    7
# 6           Adrian Hernandez   22    Male  Hispanic/Latino     March   27
# 7               Adrian Solis   35    Male  Hispanic/Latino     March   26
# 8              Alan Alverson   44    Male            White   January   28
# 9                 Alan James   31    Male            White  February    7
# 10          Albert Hanson Jr   76    Male            White     April   26
# 11            Alec Ouzounian   40    Male            White       May   12
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
killings.isnull().sum()
# Out:
# name             0
# age              0
# gender           0
# race             0
# month            0
# day              0
# year             0
# streetaddress    4
# city             0
# state            0
# agency           0
# cause            0
# armed            0
# county_income    0
# dtype: int64

# %% [markdown]
# ### 3. Replace each null/missing value in the dataframe with the string "unknown"

# %%
killings.fillna('unknown')
# Out:
#                         name  age  gender             race     month  day  \
# 0         A'donte Washington   16    Male            Black  February   23
# 1             Aaron Rutledge   27    Male            White     April    2
# 2                Aaron Siler   26    Male            White     March   14
# 3               Aaron Valdez   25    Male  Hispanic/Latino     March   11
# 4               Adam Jovicic   29    Male            White     March   19
# 5              Adam Reinhart   29    Male            White     March    7
# 6           Adrian Hernandez   22    Male  Hispanic/Latino     March   27
# 7               Adrian Solis   35    Male  Hispanic/Latino     March   26
# 8              Alan Alverson   44    Male            White   January   28
# 9                 Alan James   31    Male            White  February    7
# 10          Albert Hanson Jr   76    Male            White     April   26
# 11            Alec Ouzounian   40    Male            White       May   12
# ...

# %% [markdown]
# ### 4. How many killings were there in March and April?

# %%
kill_March = killings.month.str.contains("March").sum()

# %%
kill_April = killings.month.str.contains("April").sum()

# %%
kill_filtered = (kill_March + kill_April)
print kill_filtered
# Out:
# 210

# %% [markdown]
# ### 5. How many male and how many female victims are there?

# %%
kill_male = killings.gender.str.contains("Male").sum()
kill_male
# Out:
# 445

# %%
kill_female = killings.gender.str.contains("Female").sum()
kill_female
# Out:
# 22

# %% [markdown]
# ### 6. How many killings were of unarmed people?

# %%
kill_unarmed = (killings.armed.str.contains("No").sum())

# %%
kill_unarmed
# Out:
# 116

# %% [markdown]
# ### 7. What percentage of all killings were unarmed?

# %%
killings.shape
# Out:
# (467, 14)

# %%
unarmed = ['No']
percent_unarmed = killings[killings.armed.isin(unarmed)].head()

# %%
pct = float(kill_unarmed/467)*100

# %%
pct
# Out:
# 0.0

# %%
killings.armed.value_counts(normalize=True)
# Out:
# Firearm               0.492505
# No                    0.218415
# Knife                 0.145610
# Other                 0.055675
# Vehicle               0.038544
# Non-lethal firearm    0.029979
# Unknown               0.014989
# Disputed              0.004283
# Name: armed, dtype: float64

# %% [markdown]
# ### 8. What are the 5 states with the most killings?

# %%
killings.state.value_counts(ascending=False).head()
# Out:
# CA    74
# TX    46
# FL    29
# AZ    25
# OK    22
# Name: state, dtype: int64

# %% [markdown]
# ### 9. Show a value counts of deaths for each race

# %%
killings.race.value_counts(normalize=True)
# Out:
# White                     0.505353
# Black                     0.289079
# Hispanic/Latino           0.143469
# Unknown                   0.032120
# Asian/Pacific Islander    0.021413
# Native American           0.008565
# Name: race, dtype: float64

# %% [markdown]
# ### 10. Display a histogram of ages of all killings

# %%
killings['age'].plot(kind='hist')

# %% [markdown]
# ### 11. Show histogram of ages for each race

# %%
race_by = killings.groupby( ["race","age"]).sum()
del race_by['day']
del race_by['year']
del race_by['county_income']
killings.hist(by='race',column="age",figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x130867610>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x130d35450>]], dtype=object)

# %%
avg_age_by_race = killings.groupby('race').age.mean()

pos = np.arange(avg_age_by_race.size)

plt.figure(figsize=(15,5))

w = 0.4
plt.bar(left=pos, width=w, height=avg_age_by_race, tick_label=avg_age_by_race.index, align="center")
# Out:
# <Container object of 6 artists>

# %% [markdown]
# ### 12. What is the average age of death by race?

# %%
race_black=race_by.groupby(['race'="Black"])

# %%
by_race=killings.groupby(['age','race']).race.count()

# %%
by_race.describe
# Out:
# <bound method Series.describe of age  race
# 16   Black                     2
#      White                     1
# 17   Black                     1
#      Hispanic/Latino           1
#      White                     4
# 18   Black                     3
#      Hispanic/Latino           1
#      White                     4
# 19   Black                     2
#      Hispanic/Latino           1
#      Unknown                   1
#      White                     1
# 20   Black                     4
#      Unknown                   1
#      White                     2
# 21   Black                     3
#      Hispanic/Latino           4
#      White                     1
# 22   Black                     3
#      Hispanic/Latino           5
#      White                     2
# 23   Black                     5
#      Hispanic/Latino           2
#      Unknown                   1
#      White                     3
# 24   Black                     3
#      Hispanic/Latino           5
# ...

# %%
age_by_race=killings.groupby( ["race"]).mean()
age_by_race
# Out:
#                               age        day    year  county_income
# race
# Asian/Pacific Islander  40.800000  11.700000  2015.0   62696.800000
# Black                   34.044444  15.081481  2015.0   54181.881481
# Hispanic/Latino         31.716418  16.985075  2015.0   53257.328358
# Native American         27.750000  19.500000  2015.0   50723.500000
# Unknown                 43.533333  17.866667  2015.0   53725.466667
# White                   40.466102  15.915254  2015.0   50897.139831

# %%
killings.groupby('race').age.mean()
# Out:
# race
# Asian/Pacific Islander    40.800000
# Black                     34.044444
# Hispanic/Latino           31.716418
# Native American           27.750000
# Unknown                   43.533333
# White                     40.466102
# Name: age, dtype: float64

# %% [markdown]
# ### 13. Show a bar chart with counts of deaths every month

# %%
kill_month = killings.groupby(["month"]).month.count

kill_month()
# Out:
# month
# April        96
# February     84
# January      90
# June          2
# March       114
# May          81
# Name: month, dtype: int64

# %%
deathbymonth = killings.groupby('month').month.count()

pos = np.arange(deathbymonth.size)

plt.figure(figsize=(15,5))

w = 0.4
plt.bar(left=pos, width=w, height=deathbymonth, tick_label=deathbymonth.index, align="center")
# Out:
# /Users/WBPersonalMac/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.py:1710: MatplotlibDeprecationWarning: The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#   return func(ax, *args, **kwargs)
# <Container object of 6 artists>

# %% [markdown]
# ## Section 2: College Majors

# %%
majors = pd.read_csv('../data/college-majors.csv', index_col=[0])
majors.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %% [markdown]
# ### 1. Delete the columns (employed_full_time_year_round, major_code)

# %%
del majors['Employed_full_time_year_round']
del majors['Major_code']

# %%
majors
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
majors.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### 3. What are the top 10 highest paying majors?

# %%
top10=majors.sort_values('Median', ascending=False)

# %%
top10.head(10)
# Out:
#      Major_code                                              Major  \
# 59         2419                              PETROLEUM ENGINEERING
# 154        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 57         2417          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 55         2415                          METALLURGICAL ENGINEERING
# 58         2418                                NUCLEAR ENGINEERING
# 56         2416                     MINING AND MINERAL ENGINEERING
# 97         4005                   MATHEMATICS AND COMPUTER SCIENCE
# 48         2408                             ELECTRICAL ENGINEERING
# 45         2405                               CHEMICAL ENGINEERING
# 51         2411             GEOLOGICAL AND GEOPHYSICAL ENGINEERING
#
#               Major_category   Total  Employed  Employed_full_time_year_round  \
# 59               Engineering   19631     14002                          11636
# ...

# %%
top10.shape
# Out:
# (173, 11)

# %%
top10_df=top10.iloc[0:10, 0:11]

# %%
top10_df.head(10)
# Out:
#                                                  Major  \
# 59                               PETROLEUM ENGINEERING
# 154  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 57           NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 55                           METALLURGICAL ENGINEERING
# 58                                 NUCLEAR ENGINEERING
# 56                      MINING AND MINERAL ENGINEERING
# 97                    MATHEMATICS AND COMPUTER SCIENCE
# 48                              ELECTRICAL ENGINEERING
# 45                                CHEMICAL ENGINEERING
# 51              GEOLOGICAL AND GEOPHYSICAL ENGINEERING
#
#               Major_category   Total  Median
# 59               Engineering   19631  125000
# 154                   Health  180084  106000
# 57               Engineering   16094   97000
# 55               Engineering   12818   96000
# 58               Engineering    9826   95000
# 56               Engineering   10746   92000
# ...

# %%
del top10_df['Major_code']
del top10_df['Employed']
del top10_df['Employed_full_time_year_round']
del top10_df['Unemployed']
del top10_df['Unemployment_rate']
del top10_df['P25th']
del top10_df['P75th']
del top10_df['Major_category']
del top10_df['Total']
top10_df.set_index(['Major'],inplace=True)

# %%
top10_df.plot(
    kind='barh',
    figsize=(10,8),
    color='red',
    title='Salary vs Major',
    ec='black',
    linewidth=2.0)

# %% [markdown]
# ### 4. Plot the data from the last question in a bar chart, include proper title, and labels

# %% [markdown]
# ### 5. What is the average median salary for each major category?

# %%
top5=(top10.groupby('Major_category').Median.mean())
top5
# Out:
# Major_category
# Agriculture & Natural Resources        55000.000000
# Arts                                   43525.000000
# Biology & Life Science                 50821.428571
# Business                               60615.384615
# Communications & Journalism            49500.000000
# Computers & Mathematics                66272.727273
# Education                              43831.250000
# Engineering                            77758.620690
# Health                                 56458.333333
# Humanities & Liberal Arts              46080.000000
# Industrial Arts & Consumer Services    52642.857143
# Interdisciplinary                      43000.000000
# Law & Public Policy                    52800.000000
# Physical Sciences                      62400.000000
# Psychology & Social Work               44555.555556
# Social Science                         53222.222222
# Name: Median, dtype: float64

# %% [markdown]
# ### 6. Visualize only the top 5 paying major categories

# %%
top5.head(5)
# Out:
# Major_category
# Agriculture & Natural Resources    55000.000000
# Arts                               43525.000000
# Biology & Life Science             50821.428571
# Business                           60615.384615
# Communications & Journalism        49500.000000
# Name: Median, dtype: float64

# %% [markdown]
# ### 7. Plot a histogram of the distribution of median salaries

# %%
top5_df=pd.DataFrame(top5)
top5_df
# Out:
#                                            Median
# Major_category
# Agriculture & Natural Resources      55000.000000
# Arts                                 43525.000000
# Biology & Life Science               50821.428571
# Business                             60615.384615
# Communications & Journalism          49500.000000
# Computers & Mathematics              66272.727273
# Education                            43831.250000
# Engineering                          77758.620690
# Health                               56458.333333
# Humanities & Liberal Arts            46080.000000
# Industrial Arts & Consumer Services  52642.857143
# Interdisciplinary                    43000.000000
# Law & Public Policy                  52800.000000
# Physical Sciences                    62400.000000
# Psychology & Social Work             44555.555556
# Social Science                       53222.222222

# %%
top5_df.plot(
    kind='hist',
    figsize=(10,8),
    color='blue',
    title='Major Category and Salaries',
    ec='black',
    linewidth=2.0)

# %% [markdown]
# ### 8. Plot a histogram of the distribution of median salaries by major category

# %%
majors.hist(by='Major_category',column="Median",figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12ec8b550>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12fe28a50>]], dtype=object)

# %% [markdown]
# ### 9. What are the top 10 most UNemployed majors?

# %%
unemployedtop10=majors.sort_values('Unemployed', ascending=False)
unemployedtop10.head(10)
# Out:
#      Major_code                                   Major  \
# 161        6203  BUSINESS MANAGEMENT AND ADMINISTRATION
# 158        6200                        GENERAL BUSINESS
# 114        5200                              PSYCHOLOGY
# 159        6201                              ACCOUNTING
# 13         1901                          COMMUNICATIONS
# 73         3301         ENGLISH LANGUAGE AND LITERATURE
# 164        6206        MARKETING AND MARKETING RESEARCH
# 132        5506        POLITICAL SCIENCE AND GOVERNMENT
# 25         2300                       GENERAL EDUCATION
# 78         3600                                 BIOLOGY
#
#                   Major_category    Total  Employed  \
# 161                     Business  3123510   2354398
# 158                     Business  2148712   1580978
# 114     Psychology & Social Work  1484075   1055854
# 159                     Business  1779219   1335825
# 13   Communications & Journalism   987676    790696
# ...

# %% [markdown]
# ### 10. What are the top 10 most UNemployed majors CATEGORIES? Use the mean for each category

# %%
Unemployedcategories=(majors.groupby('Major_category').Unemployed.mean())
Unemployedcategories.head(10)
# Out:
# Major_category
# Agriculture & Natural Resources     1855.100000
# Arts                               13015.625000
# Biology & Life Science              4095.357143
# Business                           33415.153846
# Communications & Journalism        25299.750000
# Computers & Mathematics             7270.363636
# Education                           7833.500000
# Engineering                         5047.896552
# Health                              6251.083333
# Humanities & Liberal Arts          11942.400000
# Name: Unemployed, dtype: float64

# %%
unemployedcat_df=pd.DataFrame(Unemployedcategories)
unemployedcat_df
# Out:
#                                        Unemployed
# Major_category
# Agriculture & Natural Resources       1855.100000
# Arts                                 13015.625000
# Biology & Life Science                4095.357143
# Business                             33415.153846
# Communications & Journalism          25299.750000
# Computers & Mathematics               7270.363636
# Education                             7833.500000
# Engineering                           5047.896552
# Health                                6251.083333
# Humanities & Liberal Arts            11942.400000
# Industrial Arts & Consumer Services   5765.714286
# Interdisciplinary                     2990.000000
# Law & Public Policy                   8609.800000
# Physical Sciences                     3822.100000
# Psychology & Social Work             11578.444444
# Social Science                       14683.333333

# %% [markdown]
# ## Section 3: FIFA Soccer Game data

# %%
fifa = pd.read_csv('../data/fifa_data.csv')
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# ...

# %% [markdown]
# ### 1. Clean up the dataset.
#
#     - Lowercase the column names
#     - Set the "name" column as the index
#     - Drop the following columns "national_position", "national_kit", "club_kit", "club_joining", and "contract_expiry"
#     - Get rid of all players who are goalkeepers and drop every column that starts with GK
#     - Drop every player whose rating is less than 70
#     - Convert the "height" and "weight" columns to float types
#     - Check to see if there any nulls, if so drop them from the dataset

# %%
Fifa_df=pd.DataFrame(fifa)

# %%
Fifa_df.rename(columns={'Name':'name','Nationality':'nationality','National_Positioning':'national_position','National_Kit':'national_kit','Club':'club','Club_Position':'club_position','Club_Kit':'club_kit','Club_Joining':'club_joining','Contract_Expiry':'contract_expiry','Rating':'rating','Long_Shots':'long_shots','Curve':'curve','Freekick_Accuracy':'freekick_accuracy','Penalties':'penalties','Volleys':'volleys','GK_Positioning':'gk_positioning','GK_Diving':'gk_diving','GK_Kicking':'gk_kicking','GK_Handling':'gk_handling','GK_Reflexes':'gk_reflexes'},inplace=True)

# %%
Fifa_df.set_index(['name'],inplace=True)

# %%
Fifa_df.drop(["National_Position", "national_kit", "club_kit", "club_joining", "contract_expiry"],axis=1, inplace=True)

# %%
Fifa_df.columns
# Out:
# Index([u'nationality', u'club', u'club_position', u'rating', u'Height',
#        u'Weight', u'Preffered_Foot', u'Birth_Date', u'Age',
#        u'Preffered_Position', u'Work_Rate', u'Weak_foot', u'Skill_Moves',
#        u'Ball_Control', u'Dribbling', u'Marking', u'Sliding_Tackle',
#        u'Standing_Tackle', u'Aggression', u'Reactions', u'Attacking_Position',
#        u'Interceptions', u'Vision', u'Composure', u'Crossing', u'Short_Pass',
#        u'Long_Pass', u'Acceleration', u'Speed', u'Stamina', u'Strength',
#        u'Balance', u'Agility', u'Jumping', u'Heading', u'Shot_Power',
#        u'Finishing', u'long_shots', u'curve', u'freekick_accuracy',
#        u'penalties', u'volleys', u'gk_positioning', u'gk_diving',
#        u'gk_kicking', u'gk_handling', u'gk_reflexes'],
#       dtype='object')

# %%
Fifa_df=Fifa_df[Fifa_df['club_position']!='GK']

# %%
Fifa_df=Fifa_df[Fifa_df['rating']>70]

# %%
Fifa_df.columns=Fifa_df.columns.str.lower()

# %% [markdown]
# # 2.  Who are the top five players of the following attributes: speed, marking, and finishing

# %%
Fifa_df.head()
# Out:
#                    nationality          club club_position  rating  height  \
# name
# Cristiano Ronaldo     Portugal   Real Madrid            LW      94  185 cm
# Lionel Messi         Argentina  FC Barcelona            RW      93  170 cm
# Neymar                  Brazil  FC Barcelona            LW      92  174 cm
# Luis Suárez            Uruguay  FC Barcelona            ST      92  182 cm
# Robert Lewandowski      Poland     FC Bayern            ST      90  185 cm
#
#                    weight preffered_foot  birth_date  age preffered_position  \
# name
# Cristiano Ronaldo   80 kg          Right  02/05/1985   32              LW/ST
# Lionel Messi        72 kg           Left  06/24/1987   29                 RW
# Neymar              68 kg          Right  02/05/1992   25                 LW
# Luis Suárez         85 kg          Right  01/24/1987   30                 ST
# Robert Lewandowski  79 kg          Right  08/21/1988   28                 ST
#
# ...

# %%
#             sort values ascending for all three variables and print

# %% [markdown]
# ### 3. Who is the tallest French lefted foot player?

# %%
Fifa_df[(Fifa_df["preffered_foot"]=='Left') & (Fifa_df['nationality']=='France')]['height'].sort_values(ascending=False).head()
# Out:
# name
# Romain Thomas      193 cm
# Olivier Giroud     192 cm
# Jérémy Taravel     191 cm
# Nicolas Pallois    190 cm
# Jérémy Mathieu     189 cm
# Name: height, dtype: object

# %% [markdown]
# ### 4. Show a pandas series of every attribute's correlation with the rating attribute

# %%
Fifa_df.corr()['rating']
# Out:
# rating                1.000000
# age                   0.025811
# weak_foot             0.131576
# skill_moves           0.193098
# ball_control          0.308642
# dribbling             0.238015
# marking               0.051025
# sliding_tackle        0.077926
# standing_tackle       0.093141
# aggression            0.125939
# reactions             0.676555
# attacking_position    0.202916
# interceptions         0.108221
# vision                0.290809
# composure             0.422534
# crossing              0.192871
# short_pass            0.347419
# long_pass             0.286269
# acceleration          0.125838
# speed                 0.129289
# stamina               0.159912
# strength              0.096556
# balance               0.077018
# agility               0.137810
# jumping               0.092135
# heading               0.158604
# shot_power            0.229179
# finishing             0.203680
# long_shots            0.210219
# curve                 0.226459
# ...

# %% [markdown]
# ### 5. Make a heatmap of the dataset's correlation table

# %% [markdown]
# ### 6. Return a dataframe with only players from the following clubs. Call the dataframe fifa2. From now on we'll be using fifa2

# %%
clubs_list = ['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
              'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
              'Bor. Dortmund', 'Liverpool', 'Roma']

# %% [markdown]
# ### 7. Make a bar plot of the average long_shots, curve, and dribbling attributes of the clubs in the data

# %% [markdown]
# ### 8. Make a scatter plot of short_pass vs marking and use the preffered_foot column to color-encode the dots.
